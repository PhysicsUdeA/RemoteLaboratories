# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Datos.csv')

# %%
print(df)
# Out:
#      Tiempos  Voltajes
# 0       0.00      1.95
# 1       0.02      2.96
# 2       0.04      3.58
# 3       0.06      4.00
# 4       0.08      4.26
# ..       ...       ...
# 96      1.92      0.00
# 97      1.94      0.01
# 98      1.96      0.00
# 99      1.98      0.14
# 100     2.00      1.94
#
# [101 rows x 2 columns]

# %%
df.plot(x='Tiempos', y='Voltajes')
# Out:
# <AxesSubplot: xlabel='Tiempos'>
